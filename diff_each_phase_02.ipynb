# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/home/ekim_reverse/python_study/DATA_20191210_prep4_1.xlsx', sheet_name="filtered")

# %%
data.head()
# Out:
#                 RID  SEX  phase  AS1_GLU  AS2_GLU  AS3_GLU  AS4_GLU  AS5_GLU  \
# 0  EPI18_079_000033    1      4      104      113      121      140      109
# 1  EPI18_079_000051    2      3       83       99      104      108       83
# 2  EPI18_079_000069    1      2       82      138      100       91       96
# 3  EPI18_079_000075    2      6       82       89      100       99      104
# 4  EPI18_079_000126    2      4       89      103      115      132      123
#
#    AS6_GLU  AS7_GLU  ...  AS6_HBA1C  AS7_HBA1C  AS1_HOMA  AS2_HOMA  AS3_HOMA  \
# 0      105      114  ...        5.9        6.0  1.335309  1.340000  1.830000
# 1       90      112  ...        5.3        5.7  1.578025  1.980000  1.753086
# 2      111      118  ...        5.6        5.9  2.247407  3.645926  2.469136
# 3       98      123  ...        6.7        6.1  0.749136  3.823704  2.754321
# 4      126      136  ...        6.7        7.1  1.186667  3.128148  0.792593
#
# ...

# %%
data = data[data['DM']==1]

# %%
gluList_01 = data.loc[:,"AS1_GLU":"AS7_GLU"]
tgList_01 = data.loc[:,"AS1_TG":"AS7_TG"]
waistList_01 = data.loc[:,"AS1_WAIST":"AS7_WAIST"]
fib4List_01 = data.loc[:,"AS1_FIB4":"AS7_FIB4"]
hba1cList_01 = data.loc[:,"AS1_HBA1C":"AS7_HBA1C"]
tchlList_01 = data.loc[:,"AS1_TCHL":"AS7_TCHL_N"]
hsiList_01 = data.loc[:,"AS1_HSI":"AS7_HSI"]

# %%
gluList_01.columns = [1,2,3,4,5,6,7]
tgList_01.columns = [1,2,3,4,5,6,7]
waistList_01.columns = [1,2,3,4,5,6,7]
fib4List_01.columns = [1,2,3,4,5,6,7]
hba1cList_01.columns = [1,2,3,4,5,6,7]
tchlList_01.columns = [1,2,3,4,5,6,7]
hsiList_01.columns = [1,2,3,4,5,6,7]

# %%
# gluList_01 = data_test.loc[:,"AS1_GLU":"AS7_GLU"]
# tgList_01 = data_test.loc[:,"AS1_TG":"AS7_TG"]
# waistList_01 = data_test.loc[:,"AS1_WAIST":"AS7_WAIST"]
# fib4List_01 = data_test.loc[:,"AS1_FIB4":"AS7_FIB4"]
# hba1cList_01 = data_test.loc[:,"AS1_HBA1C":"AS7_HBA1C"]
# tchlList_01 = data_test.loc[:,"AS1_TCHL":"AS7_TCHL_N"]
# hsiList_01 = data_test.loc[:,"AS1_HSI":"AS7_HSI"]
# gluList_01.columns = [1,2,3,4,5,6,7]
# tgList_01.columns = [1,2,3,4,5,6,7]
# waistList_01.columns = [1,2,3,4,5,6,7]
# fib4List_01.columns = [1,2,3,4,5,6,7]
# hba1cList_01.columns = [1,2,3,4,5,6,7]
# tchlList_01.columns = [1,2,3,4,5,6,7]
# hsiList_01.columns = [1,2,3,4,5,6,7]

# %%
len(gluList_01)
# Out:
# 372

# %%
List=[gluList_01,tgList_01,waistList_01,fib4List_01,hba1cList_01,tchlList_01,hsiList_01]

# %%
len(List)
# Out:
# 7

# %%
type(data["phase"])
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# data_test = data.iloc[0:5]

# %%
# data_test

# %%
List

# %%
df_01=pd.DataFrame()
df_02=pd.DataFrame()
df_03=pd.DataFrame()
df_04=pd.DataFrame()
df_05=pd.DataFrame()
df_06=pd.DataFrame()

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_01['glu_721'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[3][i]-gluList_01[2][i])
        
df_01['glu_732'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[4][i]-gluList_01[3][i])
        
df_01['glu_743'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[5][i]-gluList_01[4][i])
        
df_01['glu_754'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[6][i]-gluList_01[5][i])
        
df_01['glu_765'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==7:
        endData.append(gluList_01[7][i]-gluList_01[6][i])
        
df_01['glu_776'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==6:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_02['glu_621'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==6:
        endData.append(gluList_01[3][i]-gluList_01[2][i])
        
df_02['glu_632'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==6:
        endData.append(gluList_01[4][i]-gluList_01[3][i])
        
df_02['glu_643'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==6:
        endData.append(gluList_01[5][i]-gluList_01[4][i])
        
df_02['glu_654'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==6:
        endData.append(gluList_01[6][i]-gluList_01[5][i])
        
df_02['glu_665'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==5:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_03['glu_521'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==5:
        endData.append(gluList_01[3][i]-gluList_01[2][i])
        
df_03['glu_532'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==5:
        endData.append(gluList_01[4][i]-gluList_01[3][i])
        
df_03['glu_543'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==5:
        endData.append(gluList_01[5][i]-gluList_01[4][i])
        
df_03['glu_554'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==4:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_04['glu_421'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==4:
        endData.append(gluList_01[3][i]-gluList_01[2][i])
        
df_04['glu_432'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==4:
        endData.append(gluList_01[4][i]-gluList_01[3][i])
        
df_04['glu_443'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==3:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_05['glu_321'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==3:
        endData.append(gluList_01[3][i]-gluList_01[2][i])
        
df_05['glu_332'] = endData

endData = []
for i in range(len(gluList_01)):
    if data["phase"][i]==2:
        endData.append(gluList_01[2][i]-gluList_01[1][i])
        
df_06['glu_221'] = endData

# %%
endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_01['tg_721'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[3][i]-tgList_01[2][i])
        
df_01['tg_732'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[4][i]-tgList_01[3][i])
        
df_01['tg_743'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[5][i]-tgList_01[4][i])
        
df_01['tg_754'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[6][i]-tgList_01[5][i])
        
df_01['tg_765'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==7:
        endData.append(tgList_01[7][i]-tgList_01[6][i])
        
df_01['tg_776'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==6:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_02['tg_621'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==6:
        endData.append(tgList_01[3][i]-tgList_01[2][i])
        
df_02['tg_632'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==6:
        endData.append(tgList_01[4][i]-tgList_01[3][i])
        
df_02['tg_643'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==6:
        endData.append(tgList_01[5][i]-tgList_01[4][i])
        
df_02['tg_654'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==6:
        endData.append(tgList_01[6][i]-tgList_01[5][i])
        
df_02['tg_665'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==5:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_03['tg_521'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==5:
        endData.append(tgList_01[3][i]-tgList_01[2][i])
        
df_03['tg_532'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==5:
        endData.append(tgList_01[4][i]-tgList_01[3][i])
        
df_03['tg_543'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==5:
        endData.append(tgList_01[5][i]-tgList_01[4][i])
        
df_03['tg_554'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==4:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_04['tg_421'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==4:
        endData.append(tgList_01[3][i]-tgList_01[2][i])
        
df_04['tg_432'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==4:
        endData.append(tgList_01[4][i]-tgList_01[3][i])
        
df_04['tg_443'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==3:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_05['tg_321'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==3:
        endData.append(tgList_01[3][i]-tgList_01[2][i])
        
df_05['tg_332'] = endData

endData = []
for i in range(len(tgList_01)):
    if data["phase"][i]==2:
        endData.append(tgList_01[2][i]-tgList_01[1][i])
        
df_06['tg_221'] = endData

# %%
endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_01['waist_721'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[3][i]-waistList_01[2][i])
        
df_01['waist_732'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[4][i]-waistList_01[3][i])
        
df_01['waist_743'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[5][i]-waistList_01[4][i])
        
df_01['waist_754'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[6][i]-waistList_01[5][i])
        
df_01['waist_765'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==7:
        endData.append(waistList_01[7][i]-waistList_01[6][i])
        
df_01['waist_776'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==6:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_02['waist_621'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==6:
        endData.append(waistList_01[3][i]-waistList_01[2][i])
        
df_02['waist_632'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==6:
        endData.append(waistList_01[4][i]-waistList_01[3][i])
        
df_02['waist_643'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==6:
        endData.append(waistList_01[5][i]-waistList_01[4][i])
        
df_02['waist_654'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==6:
        endData.append(waistList_01[6][i]-waistList_01[5][i])
        
df_02['waist_665'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==5:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_03['waist_521'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==5:
        endData.append(waistList_01[3][i]-waistList_01[2][i])
        
df_03['waist_532'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==5:
        endData.append(waistList_01[4][i]-waistList_01[3][i])
        
df_03['waist_543'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==5:
        endData.append(waistList_01[5][i]-waistList_01[4][i])
        
df_03['waist_554'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==4:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_04['waist_421'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==4:
        endData.append(waistList_01[3][i]-waistList_01[2][i])
        
df_04['waist_432'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==4:
        endData.append(waistList_01[4][i]-waistList_01[3][i])
        
df_04['waist_443'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==3:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_05['waist_321'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==3:
        endData.append(waistList_01[3][i]-waistList_01[2][i])
        
df_05['waist_332'] = endData

endData = []
for i in range(len(waistList_01)):
    if data["phase"][i]==2:
        endData.append(waistList_01[2][i]-waistList_01[1][i])
        
df_06['waist_221'] = endData

# %%
endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_01['fib4_721'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[3][i]-fib4List_01[2][i])
        
df_01['fib4_732'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[4][i]-fib4List_01[3][i])
        
df_01['fib4_743'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[5][i]-fib4List_01[4][i])
        
df_01['fib4_754'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[6][i]-fib4List_01[5][i])
        
df_01['fib4_765'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==7:
        endData.append(fib4List_01[7][i]-fib4List_01[6][i])
        
df_01['fib4_776'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==6:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_02['fib4_621'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==6:
        endData.append(fib4List_01[3][i]-fib4List_01[2][i])
        
df_02['fib4_632'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==6:
        endData.append(fib4List_01[4][i]-fib4List_01[3][i])
        
df_02['fib4_643'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==6:
        endData.append(fib4List_01[5][i]-fib4List_01[4][i])
        
df_02['fib4_654'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==6:
        endData.append(fib4List_01[6][i]-fib4List_01[5][i])
        
df_02['fib4_665'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==5:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_03['fib4_521'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==5:
        endData.append(fib4List_01[3][i]-fib4List_01[2][i])
        
df_03['fib4_532'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==5:
        endData.append(fib4List_01[4][i]-fib4List_01[3][i])
        
df_03['fib4_543'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==5:
        endData.append(fib4List_01[5][i]-fib4List_01[4][i])
        
df_03['fib4_554'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==4:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_04['fib4_421'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==4:
        endData.append(fib4List_01[3][i]-fib4List_01[2][i])
        
df_04['fib4_432'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==4:
        endData.append(fib4List_01[4][i]-fib4List_01[3][i])
        
df_04['fib4_443'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==3:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_05['fib4_321'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==3:
        endData.append(fib4List_01[3][i]-fib4List_01[2][i])
        
df_05['fib4_332'] = endData

endData = []
for i in range(len(fib4List_01)):
    if data["phase"][i]==2:
        endData.append(fib4List_01[2][i]-fib4List_01[1][i])
        
df_06['fib4_221'] = endData

# %%
endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_01['hba1c_721'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[3][i]-hba1cList_01[2][i])
        
df_01['hba1c_732'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[4][i]-hba1cList_01[3][i])
        
df_01['hba1c_743'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[5][i]-hba1cList_01[4][i])
        
df_01['hba1c_754'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[6][i]-hba1cList_01[5][i])
        
df_01['hba1c_765'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==7:
        endData.append(hba1cList_01[7][i]-hba1cList_01[6][i])
        
df_01['hba1c_776'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==6:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_02['hba1c_621'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==6:
        endData.append(hba1cList_01[3][i]-hba1cList_01[2][i])
        
df_02['hba1c_632'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==6:
        endData.append(hba1cList_01[4][i]-hba1cList_01[3][i])
        
df_02['hba1c_643'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==6:
        endData.append(hba1cList_01[5][i]-hba1cList_01[4][i])
        
df_02['hba1c_654'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==6:
        endData.append(hba1cList_01[6][i]-hba1cList_01[5][i])
        
df_02['hba1c_665'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==5:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_03['hba1c_521'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==5:
        endData.append(hba1cList_01[3][i]-hba1cList_01[2][i])
        
df_03['hba1c_532'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==5:
        endData.append(hba1cList_01[4][i]-hba1cList_01[3][i])
        
df_03['hba1c_543'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==5:
        endData.append(hba1cList_01[5][i]-hba1cList_01[4][i])
        
df_03['hba1c_554'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==4:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_04['hba1c_421'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==4:
        endData.append(hba1cList_01[3][i]-hba1cList_01[2][i])
        
df_04['hba1c_432'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==4:
        endData.append(hba1cList_01[4][i]-hba1cList_01[3][i])
        
df_04['hba1c_443'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==3:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_05['hba1c_321'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==3:
        endData.append(hba1cList_01[3][i]-hba1cList_01[2][i])
        
df_05['hba1c_332'] = endData

endData = []
for i in range(len(hba1cList_01)):
    if data["phase"][i]==2:
        endData.append(hba1cList_01[2][i]-hba1cList_01[1][i])
        
df_06['hba1c_221'] = endData

# %%
endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_01['tchl_721'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[3][i]-tchlList_01[2][i])
        
df_01['tchl_732'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[4][i]-tchlList_01[3][i])
        
df_01['tchl_743'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[5][i]-tchlList_01[4][i])
        
df_01['tchl_754'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[6][i]-tchlList_01[5][i])
        
df_01['tchl_765'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==7:
        endData.append(tchlList_01[7][i]-tchlList_01[6][i])
        
df_01['tchl_776'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==6:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_02['tchl_621'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==6:
        endData.append(tchlList_01[3][i]-tchlList_01[2][i])
        
df_02['tchl_632'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==6:
        endData.append(tchlList_01[4][i]-tchlList_01[3][i])
        
df_02['tchl_643'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==6:
        endData.append(tchlList_01[5][i]-tchlList_01[4][i])
        
df_02['tchl_654'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==6:
        endData.append(tchlList_01[6][i]-tchlList_01[5][i])
        
df_02['tchl_665'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==5:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_03['tchl_521'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==5:
        endData.append(tchlList_01[3][i]-tchlList_01[2][i])
        
df_03['tchl_532'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==5:
        endData.append(tchlList_01[4][i]-tchlList_01[3][i])
        
df_03['tchl_543'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==5:
        endData.append(tchlList_01[5][i]-tchlList_01[4][i])
        
df_03['tchl_554'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==4:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_04['tchl_421'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==4:
        endData.append(tchlList_01[3][i]-tchlList_01[2][i])
        
df_04['tchl_432'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==4:
        endData.append(tchlList_01[4][i]-tchlList_01[3][i])
        
df_04['tchl_443'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==3:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_05['tchl_321'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==3:
        endData.append(tchlList_01[3][i]-tchlList_01[2][i])
        
df_05['tchl_332'] = endData

endData = []
for i in range(len(tchlList_01)):
    if data["phase"][i]==2:
        endData.append(tchlList_01[2][i]-tchlList_01[1][i])
        
df_06['tchl_221'] = endData

# %%
endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_01['hsi_721'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[3][i]-hsiList_01[2][i])
        
df_01['hsi_732'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[4][i]-hsiList_01[3][i])
        
df_01['hsi_743'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[5][i]-hsiList_01[4][i])
        
df_01['hsi_754'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[6][i]-hsiList_01[5][i])
        
df_01['hsi_765'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==7:
        endData.append(hsiList_01[7][i]-hsiList_01[6][i])
        
df_01['hsi_776'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==6:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_02['hsi_621'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==6:
        endData.append(hsiList_01[3][i]-hsiList_01[2][i])
        
df_02['hsi_632'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==6:
        endData.append(hsiList_01[4][i]-hsiList_01[3][i])
        
df_02['hsi_643'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==6:
        endData.append(hsiList_01[5][i]-hsiList_01[4][i])
        
df_02['hsi_654'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==6:
        endData.append(hsiList_01[6][i]-hsiList_01[5][i])
        
df_02['hsi_665'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==5:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_03['hsi_521'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==5:
        endData.append(hsiList_01[3][i]-hsiList_01[2][i])
        
df_03['hsi_532'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==5:
        endData.append(hsiList_01[4][i]-hsiList_01[3][i])
        
df_03['hsi_543'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==5:
        endData.append(hsiList_01[5][i]-hsiList_01[4][i])
        
df_03['hsi_554'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==4:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_04['hsi_421'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==4:
        endData.append(hsiList_01[3][i]-hsiList_01[2][i])
        
df_04['hsi_432'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==4:
        endData.append(hsiList_01[4][i]-hsiList_01[3][i])
        
df_04['hsi_443'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==3:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_05['hsi_321'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==3:
        endData.append(hsiList_01[3][i]-hsiList_01[2][i])
        
df_05['hsi_332'] = endData

endData = []
for i in range(len(hsiList_01)):
    if data["phase"][i]==2:
        endData.append(hsiList_01[2][i]-hsiList_01[1][i])
        
df_06['hsi_221'] = endData

# %%
print(df_01)
# Out:
#     glu_721  glu_732  glu_743  glu_754  glu_765  glu_776  tg_721  tg_732  \
# 0         9        5       16      -10      -12       11     -21      50
# 1       -11        6        8        3        0       -6     -46      58
# 2        14       -4       12       -1      -16       22      -7      40
# 3         9       -8        5       13       -7       18      -4     -20
# 4        14       -6        4       15      -13        0     712    -723
# 5        10        1        7       -5       11       -3      24      57
# 6         0        0      -21       34       -1       -3      96      33
# 7         5       10        2       -8       -4        2     -21      49
# 8        10       -2       -1        8        2       -5    -107      24
# 9        16        4       -2       14        7        4     -42      74
# 10        6       -7        9       -5        0       14     -61     -38
# 11        5       -7        3        5       -2       14       4       0
# ...

# %%
# 1. 엑셀 파일 열기 w/ExcelWriter
writer = pd.ExcelWriter('/home/ekim_reverse/python_study/diff_each_phase_02.xlsx', engine='xlsxwriter')

# 2. 시트별 데이터 추가하기(1개 시트로 저장할때와 유사)
df_01.to_excel(writer, sheet_name= 'DM_7')
df_02.to_excel(writer, sheet_name= 'DM_6')
df_03.to_excel(writer, sheet_name= 'DM_5')
df_04.to_excel(writer, sheet_name= 'DM_4')
df_05.to_excel(writer, sheet_name= 'DM_3')
df_06.to_excel(writer, sheet_name= 'DM_2')

# 3. 엑셀 파일 저장하기
writer.save()

# %%
# df_test = pd.DataFrame()
# for i in List:
#     for j in i.columns:
#         for k in range(len(data['phase'])):
#             df_test = i[2][1]-i[1][1]
#             if data['phase'][k] == j:
#                 pass

# %%
# df_test

# %%
# endData=[]

# for i in List:
#     for j in range(len(List[i])):
#         for k in range(len(i.columns)):
#             if data["phase"][i]==gluList_01.columns[j]:
#                 endData.append(gluList_01[j+1][i]-gluList_01[1][i])
# df_01['phase_1_2'] = endData
# print(df_01)

# %%
# for i in List:
#     for j in i.columns:
#         for k in range(len(data['phase'])):
#             if data['phase'][k] == j:

# %%
data["phase"]==gluList_01.columns[2]

# %%
# endData=[]

# for i in List:
#     for j in i.columns:
#         for k in range(len(i.columns)):
#             if data["phase"][j]==i.columns[k]:
#                 endData.append(i[k+1][j]-gluList_01[1][j])
# df_01['phase_1_2'] = endData
# print(df_01)

# %%
# df_01=pd.DataFrame()

# endData = []
# for i in range(len(gluList_01)):
#     for j in range(len(gluList_01.columns)):
#         if data["phase"][i]==gluList_01.columns[j]:
#             endData.append(gluList_01[j+1][i]-gluList_01[1][i])
# df_01['glu_phase_1_2'] = endData
# print(df_01)

# %%
df_01=pd.DataFrame()

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[6][i])
        
df_01['ast_01'] = endData

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[5][i])
        
df_01['ast_02'] = endData

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[4][i])
        
df_01['ast_03'] = endData

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[3][i])
        
df_01['ast_04'] = endData

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[2][i])
        
df_01['ast_05'] = endData

endData = []
for i in range(len(astList_01)):
    if data["phase"][i]==7:
        endData.append(astList_01[7][i]-astList_01[1][i])
        
df_01['ast_06'] = endData

print(df_01)

# %%
endData = []
for i in range(len(gluList)):
    for j in range(len(gluList.columns)):
        if data["phase"][i]==gluList.columns[j]:
            endData.append(gluList[j+1][i]-gluList[j][i])
df['glu'] = endData
print(df)

# %%
endData = []
for i in range(len(gluList)):
    if data["phase"][i]==7:
        endData.append(gluList[7][i]-gluList[6][i])
        
df['glu'] = endData
print(df)

# %%
len(endData)

# %%
gluList[7][1]-gluList[6][1]

# %%
gluList.head(8)

# %%
gluList[7][1]

# %%
data["phase"][1]==3

# %%
data["phase"].head()

# %%
data["phase"][1]
